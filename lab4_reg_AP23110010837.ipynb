# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Make printing easier to read
np.set_printoptions(precision=4, suppress=True)
pd.set_option('display.precision', 4)

# %%
# Create a dummy CSV file
dummy_data = {'col1': [1, 2, 3, 4, 5], 'col2': ['A', 'B', 'C', 'D', 'E']}
dummy_df = pd.DataFrame(dummy_data)
dummy_df.to_csv('/content/loan_toy_simple.csv', index=False)

# %%
def minmax(a: np.ndarray):
    return (a - a.min()) / (a.max() - a.min())

salary = minmax(df['salary_lakhs'].values)
loan   = minmax(df['loan_lakhs'].values)
y      = df['approve'].values.astype(float)

X = np.column_stack([salary, loan])  # shape (n, 2)

# Quick scatter
plt.figure()
plt.scatter(X[y==1,0], X[y==1,1], label='Approved (y=1)')
plt.scatter(X[y==0,0], X[y==0,1], label='Rejected (y=0)')
plt.xlabel('Salary (scaled 0-1)')
plt.ylabel('Loan amount (scaled 0-1)')
plt.legend()
plt.title('Toy Loan Data (scaled)')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3549319443.py in <cell line: 0>()
#       2     return (a - a.min()) / (a.max() - a.min())
#       3
# ----> 4 salary = minmax(df['salary_lakhs'].values)
#       5 loan   = minmax(df['loan_lakhs'].values)
#       6 y      = df['approve'].values.astype(float)
#
# NameError: name 'df' is not defined

# %%
# Load the dummy CSV file into a DataFrame
df = pd.read_csv('/content/loan_toy_simple.csv')
display(df.head())
# Out:
#    col1 col2
# 0     1    A
# 1     2    B
# 2     3    C
# 3     4    D
# 4     5    E

# %%
def sigmoid(z):
    return 1.0 / (1.0 + np.exp(-z))

def predict_proba(W, b, X):
    return sigmoid(X @ W + b)

def log_loss(p, y):
    eps = 1e-12
    p = np.clip(p, eps, 1-eps)
    return -np.mean(y*np.log(p) + (1-y)*np.log(1-p))

def gradients(W, b, X, y):
    p = predict_proba(W, b, X)
    diff = (p - y)        # shape (n,)
    dW = (X.T @ diff) / X.shape[0]
    db = np.mean(diff)
    return dW, db, p

# %%
rng = np.random.default_rng(0)
W = rng.normal(0, 0.01, size=2)
b = 0.0
lr = 0.5
epochs = 80

print('Initial W:', W)
print('Initial b:', b)
# Out:
# Initial W: [ 0.0013 -0.0013]
# Initial b: 0.0

# %%
dW, db, p = gradients(W, b, X, y)
before = log_loss(p, y)

W = W - lr * dW
b = b - lr * db

dW2, db2, p2 = gradients(W, b, X, y)
after = log_loss(p2, y)

print('dW (first step):', dW)
print('db (first step):', db)
print('loss before:', round(before, 4), ' -> loss after:', round(after, 4))
print('W after one step:', W, '  b:', round(b, 4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2601336770.py in <cell line: 0>()
# ----> 1 dW, db, p = gradients(W, b, X, y)
#       2 before = log_loss(p, y)
#       3
#       4 W = W - lr * dW
#       5 b = b - lr * db
#
# NameError: name 'X' is not defined
